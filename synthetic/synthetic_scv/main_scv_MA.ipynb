# %%
import numpy as np
import math
import pickle
import sys

path0 = 'D:/SAWS_code'
path = path0 + '/synthetic/synthetic_scv/results'
sys.path.append(path0)

from algorithms import MA
from environments import lin_reg_env
from synthetic_instances import scv_ins

import os
import datetime

# %%
d = 10
seed_list = [10000 * (i+1) + j for i in range(20) for j in range(2)] + [10000 * (i+1) + 2 for i in range(10)]
MA_power = ['onethird', 'half', 'twothirds', 'full']
power_to_num = {'onethird':1/3, 'half':1/2, 'twothirds':2/3, 'full':1}

# main loop
for seed in seed_list:
    for power in MA_power:
        
        p = power_to_num[power]

        for N in [250, 500, 1000, 2000, 4000, 8000]:

            # check if current seed has been run
            if os.path.exists(path + '/scv_MA_{}_N{}_s{}.txt'.format(power, N, seed)):
                print('MA_{}_N{}_s{} has been done'.format(power, N, seed))
                continue

            now = datetime.datetime.now()
            print('starting MA_{}_N{}_s{}'.format(power, N, seed), 'at', now.strftime("%Y-%m-%d %H:%M:%S"))

            np.random.seed(seed)

            # initialize environment
            th_list, M = scv_ins(d, N)
            x_list = [[0]*d] * N
            sigma_x = 1
            sigma_eps = 1
            env = lin_reg_env(th_list, x_list, sigma_x, sigma_eps, M=M)
            loss = env.get_loss()
            solver = env.get_solver()

            # run Moving Average
            param = {'B':1, 'wind':math.ceil(N**p), 'compute_reg':True}
            dcsn_list, reg_list = MA(env, param, np.zeros(d), solver)

            # record results
            with open(path + '/scv_MA_{}_N{}_s{}.txt'.format(power, N, seed), 'wb') as fp:
                pickle.dump(reg_list, fp)
# Out:
# MA_onethird_N250_s10000 has been done
# MA_onethird_N500_s10000 has been done
# MA_onethird_N1000_s10000 has been done
# MA_onethird_N2000_s10000 has been done
# MA_onethird_N4000_s10000 has been done
# MA_onethird_N8000_s10000 has been done
# MA_half_N250_s10000 has been done
# MA_half_N500_s10000 has been done
# MA_half_N1000_s10000 has been done
# MA_half_N2000_s10000 has been done
# MA_half_N4000_s10000 has been done
# MA_half_N8000_s10000 has been done
# MA_twothirds_N250_s10000 has been done
# MA_twothirds_N500_s10000 has been done
# MA_twothirds_N1000_s10000 has been done
# MA_twothirds_N2000_s10000 has been done
# MA_twothirds_N4000_s10000 has been done
# MA_twothirds_N8000_s10000 has been done
# MA_full_N250_s10000 has been done
# MA_full_N500_s10000 has been done
# MA_full_N1000_s10000 has been done
# MA_full_N2000_s10000 has been done
# MA_full_N4000_s10000 has been done
# MA_full_N8000_s10000 has been done
# MA_onethird_N250_s10001 has been done
# MA_onethird_N500_s10001 has been done
# MA_onethird_N1000_s10001 has been done
# MA_onethird_N2000_s10001 has been done
# MA_onethird_N4000_s10001 has been done
# MA_onethird_N8000_s10001 has been done
# MA_half_N250_s10001 has been done
# MA_half_N500_s10001 has been done
# MA_half_N1000_s10001 has been done
# MA_half_N2000_s10001 has been done
# MA_half_N4000_s10001 has been done
# MA_half_N8000_s10001 has been done
# MA_twothirds_N250_s10001 has been done
# MA_twothirds_N500_s10001 has been done
# MA_twothirds_N1000_s10001 has been done
# MA_twothirds_N2000_s10001 has been done
# MA_twothirds_N4000_s10001 has been done
# MA_twothirds_N8000_s10001 has been done
# MA_full_N250_s10001 has been done
# MA_full_N500_s10001 has been done
# MA_full_N1000_s10001 has been done
# MA_full_N2000_s10001 has been done
# MA_full_N4000_s10001 has been done
# MA_full_N8000_s10001 has been done
# MA_onethird_N250_s20000 has been done
# MA_onethird_N500_s20000 has been done
# MA_onethird_N1000_s20000 has been done
# MA_onethird_N2000_s20000 has been done
# MA_onethird_N4000_s20000 has been done
# MA_onethird_N8000_s20000 has been done
# MA_half_N250_s20000 has been done
# MA_half_N500_s20000 has been done
# MA_half_N1000_s20000 has been done
# MA_half_N2000_s20000 has been done
# MA_half_N4000_s20000 has been done
# MA_half_N8000_s20000 has been done
# MA_twothirds_N250_s20000 has been done
# MA_twothirds_N500_s20000 has been done
# MA_twothirds_N1000_s20000 has been done
# MA_twothirds_N2000_s20000 has been done
# MA_twothirds_N4000_s20000 has been done
# MA_twothirds_N8000_s20000 has been done
# MA_full_N250_s20000 has been done
# MA_full_N500_s20000 has been done
# MA_full_N1000_s20000 has been done
# MA_full_N2000_s20000 has been done
# MA_full_N4000_s20000 has been done
# MA_full_N8000_s20000 has been done
# MA_onethird_N250_s20001 has been done
# MA_onethird_N500_s20001 has been done
# MA_onethird_N1000_s20001 has been done
# MA_onethird_N2000_s20001 has been done
# MA_onethird_N4000_s20001 has been done
# MA_onethird_N8000_s20001 has been done
# MA_half_N250_s20001 has been done
# MA_half_N500_s20001 has been done
# MA_half_N1000_s20001 has been done
# MA_half_N2000_s20001 has been done
# MA_half_N4000_s20001 has been done
# MA_half_N8000_s20001 has been done
# MA_twothirds_N250_s20001 has been done
# MA_twothirds_N500_s20001 has been done
# MA_twothirds_N1000_s20001 has been done
# MA_twothirds_N2000_s20001 has been done
# MA_twothirds_N4000_s20001 has been done
# MA_twothirds_N8000_s20001 has been done
# MA_full_N250_s20001 has been done
# MA_full_N500_s20001 has been done
# MA_full_N1000_s20001 has been done
# MA_full_N2000_s20001 has been done
# MA_full_N4000_s20001 has been done
# MA_full_N8000_s20001 has been done
# MA_onethird_N250_s30000 has been done
# MA_onethird_N500_s30000 has been done
# MA_onethird_N1000_s30000 has been done
# MA_onethird_N2000_s30000 has been done
# MA_onethird_N4000_s30000 has been done
# MA_onethird_N8000_s30000 has been done
# MA_half_N250_s30000 has been done
# MA_half_N500_s30000 has been done
# MA_half_N1000_s30000 has been done
# MA_half_N2000_s30000 has been done
# MA_half_N4000_s30000 has been done
# MA_half_N8000_s30000 has been done
# MA_twothirds_N250_s30000 has been done
# MA_twothirds_N500_s30000 has been done
# MA_twothirds_N1000_s30000 has been done
# MA_twothirds_N2000_s30000 has been done
# MA_twothirds_N4000_s30000 has been done
# MA_twothirds_N8000_s30000 has been done
# MA_full_N250_s30000 has been done
# MA_full_N500_s30000 has been done
# MA_full_N1000_s30000 has been done
# MA_full_N2000_s30000 has been done
# MA_full_N4000_s30000 has been done
# MA_full_N8000_s30000 has been done
# MA_onethird_N250_s30001 has been done
# MA_onethird_N500_s30001 has been done
# MA_onethird_N1000_s30001 has been done
# MA_onethird_N2000_s30001 has been done
# MA_onethird_N4000_s30001 has been done
# MA_onethird_N8000_s30001 has been done
# MA_half_N250_s30001 has been done
# MA_half_N500_s30001 has been done
# MA_half_N1000_s30001 has been done
# MA_half_N2000_s30001 has been done
# MA_half_N4000_s30001 has been done
# MA_half_N8000_s30001 has been done
# MA_twothirds_N250_s30001 has been done
# MA_twothirds_N500_s30001 has been done
# MA_twothirds_N1000_s30001 has been done
# MA_twothirds_N2000_s30001 has been done
# MA_twothirds_N4000_s30001 has been done
# MA_twothirds_N8000_s30001 has been done
# MA_full_N250_s30001 has been done
# MA_full_N500_s30001 has been done
# MA_full_N1000_s30001 has been done
# MA_full_N2000_s30001 has been done
# MA_full_N4000_s30001 has been done
# MA_full_N8000_s30001 has been done
# MA_onethird_N250_s40000 has been done
# MA_onethird_N500_s40000 has been done
# MA_onethird_N1000_s40000 has been done
# MA_onethird_N2000_s40000 has been done
# MA_onethird_N4000_s40000 has been done
# MA_onethird_N8000_s40000 has been done
# MA_half_N250_s40000 has been done
# MA_half_N500_s40000 has been done
# MA_half_N1000_s40000 has been done
# MA_half_N2000_s40000 has been done
# MA_half_N4000_s40000 has been done
# MA_half_N8000_s40000 has been done
# MA_twothirds_N250_s40000 has been done
# MA_twothirds_N500_s40000 has been done
# MA_twothirds_N1000_s40000 has been done
# MA_twothirds_N2000_s40000 has been done
# MA_twothirds_N4000_s40000 has been done
# MA_twothirds_N8000_s40000 has been done
# MA_full_N250_s40000 has been done
# MA_full_N500_s40000 has been done
# MA_full_N1000_s40000 has been done
# MA_full_N2000_s40000 has been done
# MA_full_N4000_s40000 has been done
# MA_full_N8000_s40000 has been done
# MA_onethird_N250_s40001 has been done
# MA_onethird_N500_s40001 has been done
# MA_onethird_N1000_s40001 has been done
# MA_onethird_N2000_s40001 has been done
# MA_onethird_N4000_s40001 has been done
# MA_onethird_N8000_s40001 has been done
# MA_half_N250_s40001 has been done
# MA_half_N500_s40001 has been done
# MA_half_N1000_s40001 has been done
# MA_half_N2000_s40001 has been done
# MA_half_N4000_s40001 has been done
# MA_half_N8000_s40001 has been done
# MA_twothirds_N250_s40001 has been done
# MA_twothirds_N500_s40001 has been done
# MA_twothirds_N1000_s40001 has been done
# MA_twothirds_N2000_s40001 has been done
# MA_twothirds_N4000_s40001 has been done
# MA_twothirds_N8000_s40001 has been done
# MA_full_N250_s40001 has been done
# MA_full_N500_s40001 has been done
# MA_full_N1000_s40001 has been done
# MA_full_N2000_s40001 has been done
# MA_full_N4000_s40001 has been done
# MA_full_N8000_s40001 has been done
# MA_onethird_N250_s50000 has been done
# MA_onethird_N500_s50000 has been done
# MA_onethird_N1000_s50000 has been done
# MA_onethird_N2000_s50000 has been done
# MA_onethird_N4000_s50000 has been done
# MA_onethird_N8000_s50000 has been done
# MA_half_N250_s50000 has been done
# MA_half_N500_s50000 has been done
# MA_half_N1000_s50000 has been done
# MA_half_N2000_s50000 has been done
# MA_half_N4000_s50000 has been done
# MA_half_N8000_s50000 has been done
# MA_twothirds_N250_s50000 has been done
# MA_twothirds_N500_s50000 has been done
# MA_twothirds_N1000_s50000 has been done
# MA_twothirds_N2000_s50000 has been done
# MA_twothirds_N4000_s50000 has been done
# MA_twothirds_N8000_s50000 has been done
# MA_full_N250_s50000 has been done
# MA_full_N500_s50000 has been done
# MA_full_N1000_s50000 has been done
# MA_full_N2000_s50000 has been done
# MA_full_N4000_s50000 has been done
# MA_full_N8000_s50000 has been done
# MA_onethird_N250_s50001 has been done
# MA_onethird_N500_s50001 has been done
# MA_onethird_N1000_s50001 has been done
# MA_onethird_N2000_s50001 has been done
# MA_onethird_N4000_s50001 has been done
# MA_onethird_N8000_s50001 has been done
# MA_half_N250_s50001 has been done
# MA_half_N500_s50001 has been done
# MA_half_N1000_s50001 has been done
# MA_half_N2000_s50001 has been done
# MA_half_N4000_s50001 has been done
# MA_half_N8000_s50001 has been done
# MA_twothirds_N250_s50001 has been done
# MA_twothirds_N500_s50001 has been done
# MA_twothirds_N1000_s50001 has been done
# MA_twothirds_N2000_s50001 has been done
# MA_twothirds_N4000_s50001 has been done
# MA_twothirds_N8000_s50001 has been done
# MA_full_N250_s50001 has been done
# MA_full_N500_s50001 has been done
# MA_full_N1000_s50001 has been done
# MA_full_N2000_s50001 has been done
# MA_full_N4000_s50001 has been done
# MA_full_N8000_s50001 has been done
# MA_onethird_N250_s60000 has been done
# MA_onethird_N500_s60000 has been done
# MA_onethird_N1000_s60000 has been done
# MA_onethird_N2000_s60000 has been done
# MA_onethird_N4000_s60000 has been done
# MA_onethird_N8000_s60000 has been done
# MA_half_N250_s60000 has been done
# MA_half_N500_s60000 has been done
# MA_half_N1000_s60000 has been done
# MA_half_N2000_s60000 has been done
# MA_half_N4000_s60000 has been done
# MA_half_N8000_s60000 has been done
# MA_twothirds_N250_s60000 has been done
# MA_twothirds_N500_s60000 has been done
# MA_twothirds_N1000_s60000 has been done
# MA_twothirds_N2000_s60000 has been done
# MA_twothirds_N4000_s60000 has been done
# MA_twothirds_N8000_s60000 has been done
# MA_full_N250_s60000 has been done
# MA_full_N500_s60000 has been done
# MA_full_N1000_s60000 has been done
# MA_full_N2000_s60000 has been done
# MA_full_N4000_s60000 has been done
# MA_full_N8000_s60000 has been done
# MA_onethird_N250_s60001 has been done
# MA_onethird_N500_s60001 has been done
# MA_onethird_N1000_s60001 has been done
# MA_onethird_N2000_s60001 has been done
# MA_onethird_N4000_s60001 has been done
# MA_onethird_N8000_s60001 has been done
# MA_half_N250_s60001 has been done
# MA_half_N500_s60001 has been done
# MA_half_N1000_s60001 has been done
# MA_half_N2000_s60001 has been done
# MA_half_N4000_s60001 has been done
# MA_half_N8000_s60001 has been done
# MA_twothirds_N250_s60001 has been done
# MA_twothirds_N500_s60001 has been done
# MA_twothirds_N1000_s60001 has been done
# MA_twothirds_N2000_s60001 has been done
# MA_twothirds_N4000_s60001 has been done
# MA_twothirds_N8000_s60001 has been done
# MA_full_N250_s60001 has been done
# MA_full_N500_s60001 has been done
# MA_full_N1000_s60001 has been done
# MA_full_N2000_s60001 has been done
# MA_full_N4000_s60001 has been done
# MA_full_N8000_s60001 has been done
# MA_onethird_N250_s70000 has been done
# MA_onethird_N500_s70000 has been done
# MA_onethird_N1000_s70000 has been done
# MA_onethird_N2000_s70000 has been done
# MA_onethird_N4000_s70000 has been done
# MA_onethird_N8000_s70000 has been done
# MA_half_N250_s70000 has been done
# MA_half_N500_s70000 has been done
# MA_half_N1000_s70000 has been done
# MA_half_N2000_s70000 has been done
# MA_half_N4000_s70000 has been done
# MA_half_N8000_s70000 has been done
# MA_twothirds_N250_s70000 has been done
# MA_twothirds_N500_s70000 has been done
# MA_twothirds_N1000_s70000 has been done
# MA_twothirds_N2000_s70000 has been done
# MA_twothirds_N4000_s70000 has been done
# MA_twothirds_N8000_s70000 has been done
# MA_full_N250_s70000 has been done
# MA_full_N500_s70000 has been done
# MA_full_N1000_s70000 has been done
# MA_full_N2000_s70000 has been done
# MA_full_N4000_s70000 has been done
# MA_full_N8000_s70000 has been done
# MA_onethird_N250_s70001 has been done
# MA_onethird_N500_s70001 has been done
# MA_onethird_N1000_s70001 has been done
# MA_onethird_N2000_s70001 has been done
# MA_onethird_N4000_s70001 has been done
# MA_onethird_N8000_s70001 has been done
# MA_half_N250_s70001 has been done
# MA_half_N500_s70001 has been done
# MA_half_N1000_s70001 has been done
# MA_half_N2000_s70001 has been done
# MA_half_N4000_s70001 has been done
# MA_half_N8000_s70001 has been done
# MA_twothirds_N250_s70001 has been done
# MA_twothirds_N500_s70001 has been done
# MA_twothirds_N1000_s70001 has been done
# MA_twothirds_N2000_s70001 has been done
# MA_twothirds_N4000_s70001 has been done
# MA_twothirds_N8000_s70001 has been done
# MA_full_N250_s70001 has been done
# MA_full_N500_s70001 has been done
# MA_full_N1000_s70001 has been done
# MA_full_N2000_s70001 has been done
# MA_full_N4000_s70001 has been done
# MA_full_N8000_s70001 has been done
# MA_onethird_N250_s80000 has been done
# MA_onethird_N500_s80000 has been done
# MA_onethird_N1000_s80000 has been done
# MA_onethird_N2000_s80000 has been done
# MA_onethird_N4000_s80000 has been done
# MA_onethird_N8000_s80000 has been done
# MA_half_N250_s80000 has been done
# MA_half_N500_s80000 has been done
# MA_half_N1000_s80000 has been done
# MA_half_N2000_s80000 has been done
# MA_half_N4000_s80000 has been done
# MA_half_N8000_s80000 has been done
# MA_twothirds_N250_s80000 has been done
# MA_twothirds_N500_s80000 has been done
# MA_twothirds_N1000_s80000 has been done
# MA_twothirds_N2000_s80000 has been done
# MA_twothirds_N4000_s80000 has been done
# MA_twothirds_N8000_s80000 has been done
# MA_full_N250_s80000 has been done
# MA_full_N500_s80000 has been done
# MA_full_N1000_s80000 has been done
# MA_full_N2000_s80000 has been done
# MA_full_N4000_s80000 has been done
# MA_full_N8000_s80000 has been done
# MA_onethird_N250_s80001 has been done
# MA_onethird_N500_s80001 has been done
# MA_onethird_N1000_s80001 has been done
# MA_onethird_N2000_s80001 has been done
# MA_onethird_N4000_s80001 has been done
# MA_onethird_N8000_s80001 has been done
# MA_half_N250_s80001 has been done
# MA_half_N500_s80001 has been done
# MA_half_N1000_s80001 has been done
# MA_half_N2000_s80001 has been done
# MA_half_N4000_s80001 has been done
# MA_half_N8000_s80001 has been done
# MA_twothirds_N250_s80001 has been done
# MA_twothirds_N500_s80001 has been done
# MA_twothirds_N1000_s80001 has been done
# MA_twothirds_N2000_s80001 has been done
# MA_twothirds_N4000_s80001 has been done
# MA_twothirds_N8000_s80001 has been done
# MA_full_N250_s80001 has been done
# MA_full_N500_s80001 has been done
# MA_full_N1000_s80001 has been done
# MA_full_N2000_s80001 has been done
# MA_full_N4000_s80001 has been done
# MA_full_N8000_s80001 has been done
# MA_onethird_N250_s90000 has been done
# MA_onethird_N500_s90000 has been done
# MA_onethird_N1000_s90000 has been done
# MA_onethird_N2000_s90000 has been done
# MA_onethird_N4000_s90000 has been done
# MA_onethird_N8000_s90000 has been done
# MA_half_N250_s90000 has been done
# MA_half_N500_s90000 has been done
# MA_half_N1000_s90000 has been done
# MA_half_N2000_s90000 has been done
# MA_half_N4000_s90000 has been done
# MA_half_N8000_s90000 has been done
# MA_twothirds_N250_s90000 has been done
# MA_twothirds_N500_s90000 has been done
# MA_twothirds_N1000_s90000 has been done
# MA_twothirds_N2000_s90000 has been done
# MA_twothirds_N4000_s90000 has been done
# MA_twothirds_N8000_s90000 has been done
# MA_full_N250_s90000 has been done
# MA_full_N500_s90000 has been done
# MA_full_N1000_s90000 has been done
# MA_full_N2000_s90000 has been done
# MA_full_N4000_s90000 has been done
# MA_full_N8000_s90000 has been done
# MA_onethird_N250_s90001 has been done
# MA_onethird_N500_s90001 has been done
# MA_onethird_N1000_s90001 has been done
# MA_onethird_N2000_s90001 has been done
# MA_onethird_N4000_s90001 has been done
# MA_onethird_N8000_s90001 has been done
# MA_half_N250_s90001 has been done
# MA_half_N500_s90001 has been done
# MA_half_N1000_s90001 has been done
# MA_half_N2000_s90001 has been done
# MA_half_N4000_s90001 has been done
# MA_half_N8000_s90001 has been done
# MA_twothirds_N250_s90001 has been done
# MA_twothirds_N500_s90001 has been done
# MA_twothirds_N1000_s90001 has been done
# MA_twothirds_N2000_s90001 has been done
# MA_twothirds_N4000_s90001 has been done
# MA_twothirds_N8000_s90001 has been done
# MA_full_N250_s90001 has been done
# MA_full_N500_s90001 has been done
# MA_full_N1000_s90001 has been done
# MA_full_N2000_s90001 has been done
# MA_full_N4000_s90001 has been done
# MA_full_N8000_s90001 has been done
# MA_onethird_N250_s100000 has been done
# MA_onethird_N500_s100000 has been done
# MA_onethird_N1000_s100000 has been done
# MA_onethird_N2000_s100000 has been done
# MA_onethird_N4000_s100000 has been done
# MA_onethird_N8000_s100000 has been done
# MA_half_N250_s100000 has been done
# MA_half_N500_s100000 has been done
# MA_half_N1000_s100000 has been done
# MA_half_N2000_s100000 has been done
# MA_half_N4000_s100000 has been done
# MA_half_N8000_s100000 has been done
# MA_twothirds_N250_s100000 has been done
# MA_twothirds_N500_s100000 has been done
# MA_twothirds_N1000_s100000 has been done
# MA_twothirds_N2000_s100000 has been done
# MA_twothirds_N4000_s100000 has been done
# MA_twothirds_N8000_s100000 has been done
# MA_full_N250_s100000 has been done
# MA_full_N500_s100000 has been done
# MA_full_N1000_s100000 has been done
# MA_full_N2000_s100000 has been done
# MA_full_N4000_s100000 has been done
# MA_full_N8000_s100000 has been done
# MA_onethird_N250_s100001 has been done
# MA_onethird_N500_s100001 has been done
# MA_onethird_N1000_s100001 has been done
# MA_onethird_N2000_s100001 has been done
# MA_onethird_N4000_s100001 has been done
# MA_onethird_N8000_s100001 has been done
# MA_half_N250_s100001 has been done
# MA_half_N500_s100001 has been done
# MA_half_N1000_s100001 has been done
# MA_half_N2000_s100001 has been done
# MA_half_N4000_s100001 has been done
# MA_half_N8000_s100001 has been done
# MA_twothirds_N250_s100001 has been done
# MA_twothirds_N500_s100001 has been done
# MA_twothirds_N1000_s100001 has been done
# MA_twothirds_N2000_s100001 has been done
# MA_twothirds_N4000_s100001 has been done
# MA_twothirds_N8000_s100001 has been done
# MA_full_N250_s100001 has been done
# MA_full_N500_s100001 has been done
# MA_full_N1000_s100001 has been done
# MA_full_N2000_s100001 has been done
# MA_full_N4000_s100001 has been done
# MA_full_N8000_s100001 has been done
# MA_onethird_N250_s110000 has been done
# MA_onethird_N500_s110000 has been done
# MA_onethird_N1000_s110000 has been done
# MA_onethird_N2000_s110000 has been done
# MA_onethird_N4000_s110000 has been done
# MA_onethird_N8000_s110000 has been done
# MA_half_N250_s110000 has been done
# MA_half_N500_s110000 has been done
# MA_half_N1000_s110000 has been done
# MA_half_N2000_s110000 has been done
# MA_half_N4000_s110000 has been done
# MA_half_N8000_s110000 has been done
# MA_twothirds_N250_s110000 has been done
# MA_twothirds_N500_s110000 has been done
# MA_twothirds_N1000_s110000 has been done
# MA_twothirds_N2000_s110000 has been done
# MA_twothirds_N4000_s110000 has been done
# MA_twothirds_N8000_s110000 has been done
# MA_full_N250_s110000 has been done
# MA_full_N500_s110000 has been done
# MA_full_N1000_s110000 has been done
# MA_full_N2000_s110000 has been done
# MA_full_N4000_s110000 has been done
# MA_full_N8000_s110000 has been done
# MA_onethird_N250_s110001 has been done
# MA_onethird_N500_s110001 has been done
# MA_onethird_N1000_s110001 has been done
# MA_onethird_N2000_s110001 has been done
# MA_onethird_N4000_s110001 has been done
# MA_onethird_N8000_s110001 has been done
# MA_half_N250_s110001 has been done
# MA_half_N500_s110001 has been done
# MA_half_N1000_s110001 has been done
# MA_half_N2000_s110001 has been done
# MA_half_N4000_s110001 has been done
# MA_half_N8000_s110001 has been done
# MA_twothirds_N250_s110001 has been done
# MA_twothirds_N500_s110001 has been done
# MA_twothirds_N1000_s110001 has been done
# MA_twothirds_N2000_s110001 has been done
# MA_twothirds_N4000_s110001 has been done
# MA_twothirds_N8000_s110001 has been done
# MA_full_N250_s110001 has been done
# MA_full_N500_s110001 has been done
# MA_full_N1000_s110001 has been done
# MA_full_N2000_s110001 has been done
# MA_full_N4000_s110001 has been done
# MA_full_N8000_s110001 has been done
# MA_onethird_N250_s120000 has been done
# MA_onethird_N500_s120000 has been done
# MA_onethird_N1000_s120000 has been done
# MA_onethird_N2000_s120000 has been done
# MA_onethird_N4000_s120000 has been done
# MA_onethird_N8000_s120000 has been done
# MA_half_N250_s120000 has been done
# MA_half_N500_s120000 has been done
# MA_half_N1000_s120000 has been done
# MA_half_N2000_s120000 has been done
# MA_half_N4000_s120000 has been done
# MA_half_N8000_s120000 has been done
# MA_twothirds_N250_s120000 has been done
# MA_twothirds_N500_s120000 has been done
# MA_twothirds_N1000_s120000 has been done
# MA_twothirds_N2000_s120000 has been done
# MA_twothirds_N4000_s120000 has been done
# MA_twothirds_N8000_s120000 has been done
# MA_full_N250_s120000 has been done
# MA_full_N500_s120000 has been done
# MA_full_N1000_s120000 has been done
# MA_full_N2000_s120000 has been done
# MA_full_N4000_s120000 has been done
# MA_full_N8000_s120000 has been done
# MA_onethird_N250_s120001 has been done
# MA_onethird_N500_s120001 has been done
# MA_onethird_N1000_s120001 has been done
# MA_onethird_N2000_s120001 has been done
# MA_onethird_N4000_s120001 has been done
# MA_onethird_N8000_s120001 has been done
# MA_half_N250_s120001 has been done
# MA_half_N500_s120001 has been done
# MA_half_N1000_s120001 has been done
# MA_half_N2000_s120001 has been done
# MA_half_N4000_s120001 has been done
# MA_half_N8000_s120001 has been done
# MA_twothirds_N250_s120001 has been done
# MA_twothirds_N500_s120001 has been done
# MA_twothirds_N1000_s120001 has been done
# MA_twothirds_N2000_s120001 has been done
# MA_twothirds_N4000_s120001 has been done
# MA_twothirds_N8000_s120001 has been done
# MA_full_N250_s120001 has been done
# MA_full_N500_s120001 has been done
# MA_full_N1000_s120001 has been done
# MA_full_N2000_s120001 has been done
# MA_full_N4000_s120001 has been done
# MA_full_N8000_s120001 has been done
# MA_onethird_N250_s130000 has been done
# MA_onethird_N500_s130000 has been done
# MA_onethird_N1000_s130000 has been done
# MA_onethird_N2000_s130000 has been done
# MA_onethird_N4000_s130000 has been done
# MA_onethird_N8000_s130000 has been done
# MA_half_N250_s130000 has been done
# MA_half_N500_s130000 has been done
# MA_half_N1000_s130000 has been done
# MA_half_N2000_s130000 has been done
# MA_half_N4000_s130000 has been done
# MA_half_N8000_s130000 has been done
# MA_twothirds_N250_s130000 has been done
# MA_twothirds_N500_s130000 has been done
# MA_twothirds_N1000_s130000 has been done
# MA_twothirds_N2000_s130000 has been done
# MA_twothirds_N4000_s130000 has been done
# MA_twothirds_N8000_s130000 has been done
# MA_full_N250_s130000 has been done
# MA_full_N500_s130000 has been done
# MA_full_N1000_s130000 has been done
# MA_full_N2000_s130000 has been done
# MA_full_N4000_s130000 has been done
# MA_full_N8000_s130000 has been done
# MA_onethird_N250_s130001 has been done
# MA_onethird_N500_s130001 has been done
# MA_onethird_N1000_s130001 has been done
# MA_onethird_N2000_s130001 has been done
# MA_onethird_N4000_s130001 has been done
# MA_onethird_N8000_s130001 has been done
# MA_half_N250_s130001 has been done
# MA_half_N500_s130001 has been done
# MA_half_N1000_s130001 has been done
# MA_half_N2000_s130001 has been done
# MA_half_N4000_s130001 has been done
# MA_half_N8000_s130001 has been done
# MA_twothirds_N250_s130001 has been done
# MA_twothirds_N500_s130001 has been done
# MA_twothirds_N1000_s130001 has been done
# MA_twothirds_N2000_s130001 has been done
# MA_twothirds_N4000_s130001 has been done
# MA_twothirds_N8000_s130001 has been done
# MA_full_N250_s130001 has been done
# MA_full_N500_s130001 has been done
# MA_full_N1000_s130001 has been done
# MA_full_N2000_s130001 has been done
# MA_full_N4000_s130001 has been done
# MA_full_N8000_s130001 has been done
# MA_onethird_N250_s140000 has been done
# MA_onethird_N500_s140000 has been done
# MA_onethird_N1000_s140000 has been done
# MA_onethird_N2000_s140000 has been done
# MA_onethird_N4000_s140000 has been done
# MA_onethird_N8000_s140000 has been done
# MA_half_N250_s140000 has been done
# MA_half_N500_s140000 has been done
# MA_half_N1000_s140000 has been done
# MA_half_N2000_s140000 has been done
# MA_half_N4000_s140000 has been done
# MA_half_N8000_s140000 has been done
# MA_twothirds_N250_s140000 has been done
# MA_twothirds_N500_s140000 has been done
# MA_twothirds_N1000_s140000 has been done
# MA_twothirds_N2000_s140000 has been done
# MA_twothirds_N4000_s140000 has been done
# MA_twothirds_N8000_s140000 has been done
# MA_full_N250_s140000 has been done
# MA_full_N500_s140000 has been done
# MA_full_N1000_s140000 has been done
# MA_full_N2000_s140000 has been done
# MA_full_N4000_s140000 has been done
# MA_full_N8000_s140000 has been done
# MA_onethird_N250_s140001 has been done
# MA_onethird_N500_s140001 has been done
# MA_onethird_N1000_s140001 has been done
# MA_onethird_N2000_s140001 has been done
# MA_onethird_N4000_s140001 has been done
# MA_onethird_N8000_s140001 has been done
# MA_half_N250_s140001 has been done
# MA_half_N500_s140001 has been done
# MA_half_N1000_s140001 has been done
# MA_half_N2000_s140001 has been done
# MA_half_N4000_s140001 has been done
# MA_half_N8000_s140001 has been done
# MA_twothirds_N250_s140001 has been done
# MA_twothirds_N500_s140001 has been done
# MA_twothirds_N1000_s140001 has been done
# MA_twothirds_N2000_s140001 has been done
# MA_twothirds_N4000_s140001 has been done
# MA_twothirds_N8000_s140001 has been done
# MA_full_N250_s140001 has been done
# MA_full_N500_s140001 has been done
# MA_full_N1000_s140001 has been done
# MA_full_N2000_s140001 has been done
# MA_full_N4000_s140001 has been done
# MA_full_N8000_s140001 has been done
# MA_onethird_N250_s150000 has been done
# MA_onethird_N500_s150000 has been done
# MA_onethird_N1000_s150000 has been done
# MA_onethird_N2000_s150000 has been done
# MA_onethird_N4000_s150000 has been done
# MA_onethird_N8000_s150000 has been done
# MA_half_N250_s150000 has been done
# MA_half_N500_s150000 has been done
# MA_half_N1000_s150000 has been done
# MA_half_N2000_s150000 has been done
# MA_half_N4000_s150000 has been done
# MA_half_N8000_s150000 has been done
# MA_twothirds_N250_s150000 has been done
# MA_twothirds_N500_s150000 has been done
# MA_twothirds_N1000_s150000 has been done
# MA_twothirds_N2000_s150000 has been done
# MA_twothirds_N4000_s150000 has been done
# MA_twothirds_N8000_s150000 has been done
# MA_full_N250_s150000 has been done
# MA_full_N500_s150000 has been done
# MA_full_N1000_s150000 has been done
# MA_full_N2000_s150000 has been done
# MA_full_N4000_s150000 has been done
# MA_full_N8000_s150000 has been done
# MA_onethird_N250_s150001 has been done
# MA_onethird_N500_s150001 has been done
# MA_onethird_N1000_s150001 has been done
# MA_onethird_N2000_s150001 has been done
# MA_onethird_N4000_s150001 has been done
# MA_onethird_N8000_s150001 has been done
# MA_half_N250_s150001 has been done
# MA_half_N500_s150001 has been done
# MA_half_N1000_s150001 has been done
# MA_half_N2000_s150001 has been done
# MA_half_N4000_s150001 has been done
# MA_half_N8000_s150001 has been done
# MA_twothirds_N250_s150001 has been done
# MA_twothirds_N500_s150001 has been done
# MA_twothirds_N1000_s150001 has been done
# MA_twothirds_N2000_s150001 has been done
# MA_twothirds_N4000_s150001 has been done
# MA_twothirds_N8000_s150001 has been done
# MA_full_N250_s150001 has been done
# MA_full_N500_s150001 has been done
# MA_full_N1000_s150001 has been done
# MA_full_N2000_s150001 has been done
# MA_full_N4000_s150001 has been done
# MA_full_N8000_s150001 has been done
# MA_onethird_N250_s160000 has been done
# MA_onethird_N500_s160000 has been done
# MA_onethird_N1000_s160000 has been done
# MA_onethird_N2000_s160000 has been done
# MA_onethird_N4000_s160000 has been done
# MA_onethird_N8000_s160000 has been done
# MA_half_N250_s160000 has been done
# MA_half_N500_s160000 has been done
# MA_half_N1000_s160000 has been done
# MA_half_N2000_s160000 has been done
# MA_half_N4000_s160000 has been done
# MA_half_N8000_s160000 has been done
# MA_twothirds_N250_s160000 has been done
# MA_twothirds_N500_s160000 has been done
# MA_twothirds_N1000_s160000 has been done
# MA_twothirds_N2000_s160000 has been done
# MA_twothirds_N4000_s160000 has been done
# MA_twothirds_N8000_s160000 has been done
# MA_full_N250_s160000 has been done
# MA_full_N500_s160000 has been done
# MA_full_N1000_s160000 has been done
# MA_full_N2000_s160000 has been done
# MA_full_N4000_s160000 has been done
# MA_full_N8000_s160000 has been done
# MA_onethird_N250_s160001 has been done
# MA_onethird_N500_s160001 has been done
# MA_onethird_N1000_s160001 has been done
# MA_onethird_N2000_s160001 has been done
# MA_onethird_N4000_s160001 has been done
# MA_onethird_N8000_s160001 has been done
# MA_half_N250_s160001 has been done
# MA_half_N500_s160001 has been done
# MA_half_N1000_s160001 has been done
# MA_half_N2000_s160001 has been done
# MA_half_N4000_s160001 has been done
# MA_half_N8000_s160001 has been done
# MA_twothirds_N250_s160001 has been done
# MA_twothirds_N500_s160001 has been done
# MA_twothirds_N1000_s160001 has been done
# MA_twothirds_N2000_s160001 has been done
# MA_twothirds_N4000_s160001 has been done
# MA_twothirds_N8000_s160001 has been done
# MA_full_N250_s160001 has been done
# MA_full_N500_s160001 has been done
# MA_full_N1000_s160001 has been done
# MA_full_N2000_s160001 has been done
# MA_full_N4000_s160001 has been done
# MA_full_N8000_s160001 has been done
# MA_onethird_N250_s170000 has been done
# MA_onethird_N500_s170000 has been done
# MA_onethird_N1000_s170000 has been done
# MA_onethird_N2000_s170000 has been done
# MA_onethird_N4000_s170000 has been done
# MA_onethird_N8000_s170000 has been done
# MA_half_N250_s170000 has been done
# MA_half_N500_s170000 has been done
# MA_half_N1000_s170000 has been done
# MA_half_N2000_s170000 has been done
# MA_half_N4000_s170000 has been done
# MA_half_N8000_s170000 has been done
# MA_twothirds_N250_s170000 has been done
# MA_twothirds_N500_s170000 has been done
# MA_twothirds_N1000_s170000 has been done
# MA_twothirds_N2000_s170000 has been done
# MA_twothirds_N4000_s170000 has been done
# MA_twothirds_N8000_s170000 has been done
# MA_full_N250_s170000 has been done
# MA_full_N500_s170000 has been done
# MA_full_N1000_s170000 has been done
# MA_full_N2000_s170000 has been done
# MA_full_N4000_s170000 has been done
# MA_full_N8000_s170000 has been done
# MA_onethird_N250_s170001 has been done
# MA_onethird_N500_s170001 has been done
# MA_onethird_N1000_s170001 has been done
# MA_onethird_N2000_s170001 has been done
# MA_onethird_N4000_s170001 has been done
# MA_onethird_N8000_s170001 has been done
# MA_half_N250_s170001 has been done
# MA_half_N500_s170001 has been done
# MA_half_N1000_s170001 has been done
# MA_half_N2000_s170001 has been done
# MA_half_N4000_s170001 has been done
# MA_half_N8000_s170001 has been done
# MA_twothirds_N250_s170001 has been done
# MA_twothirds_N500_s170001 has been done
# MA_twothirds_N1000_s170001 has been done
# MA_twothirds_N2000_s170001 has been done
# MA_twothirds_N4000_s170001 has been done
# MA_twothirds_N8000_s170001 has been done
# MA_full_N250_s170001 has been done
# MA_full_N500_s170001 has been done
# MA_full_N1000_s170001 has been done
# MA_full_N2000_s170001 has been done
# MA_full_N4000_s170001 has been done
# MA_full_N8000_s170001 has been done
# MA_onethird_N250_s180000 has been done
# MA_onethird_N500_s180000 has been done
# MA_onethird_N1000_s180000 has been done
# MA_onethird_N2000_s180000 has been done
# MA_onethird_N4000_s180000 has been done
# MA_onethird_N8000_s180000 has been done
# MA_half_N250_s180000 has been done
# MA_half_N500_s180000 has been done
# MA_half_N1000_s180000 has been done
# MA_half_N2000_s180000 has been done
# MA_half_N4000_s180000 has been done
# MA_half_N8000_s180000 has been done
# MA_twothirds_N250_s180000 has been done
# MA_twothirds_N500_s180000 has been done
# MA_twothirds_N1000_s180000 has been done
# MA_twothirds_N2000_s180000 has been done
# MA_twothirds_N4000_s180000 has been done
# MA_twothirds_N8000_s180000 has been done
# MA_full_N250_s180000 has been done
# MA_full_N500_s180000 has been done
# MA_full_N1000_s180000 has been done
# MA_full_N2000_s180000 has been done
# MA_full_N4000_s180000 has been done
# MA_full_N8000_s180000 has been done
# MA_onethird_N250_s180001 has been done
# MA_onethird_N500_s180001 has been done
# MA_onethird_N1000_s180001 has been done
# MA_onethird_N2000_s180001 has been done
# MA_onethird_N4000_s180001 has been done
# MA_onethird_N8000_s180001 has been done
# MA_half_N250_s180001 has been done
# MA_half_N500_s180001 has been done
# MA_half_N1000_s180001 has been done
# MA_half_N2000_s180001 has been done
# MA_half_N4000_s180001 has been done
# MA_half_N8000_s180001 has been done
# MA_twothirds_N250_s180001 has been done
# MA_twothirds_N500_s180001 has been done
# MA_twothirds_N1000_s180001 has been done
# MA_twothirds_N2000_s180001 has been done
# MA_twothirds_N4000_s180001 has been done
# MA_twothirds_N8000_s180001 has been done
# MA_full_N250_s180001 has been done
# MA_full_N500_s180001 has been done
# MA_full_N1000_s180001 has been done
# MA_full_N2000_s180001 has been done
# MA_full_N4000_s180001 has been done
# MA_full_N8000_s180001 has been done
# MA_onethird_N250_s190000 has been done
# MA_onethird_N500_s190000 has been done
# MA_onethird_N1000_s190000 has been done
# MA_onethird_N2000_s190000 has been done
# MA_onethird_N4000_s190000 has been done
# MA_onethird_N8000_s190000 has been done
# MA_half_N250_s190000 has been done
# MA_half_N500_s190000 has been done
# MA_half_N1000_s190000 has been done
# MA_half_N2000_s190000 has been done
# MA_half_N4000_s190000 has been done
# MA_half_N8000_s190000 has been done
# MA_twothirds_N250_s190000 has been done
# MA_twothirds_N500_s190000 has been done
# MA_twothirds_N1000_s190000 has been done
# MA_twothirds_N2000_s190000 has been done
# MA_twothirds_N4000_s190000 has been done
# MA_twothirds_N8000_s190000 has been done
# MA_full_N250_s190000 has been done
# MA_full_N500_s190000 has been done
# MA_full_N1000_s190000 has been done
# MA_full_N2000_s190000 has been done
# MA_full_N4000_s190000 has been done
# MA_full_N8000_s190000 has been done
# MA_onethird_N250_s190001 has been done
# MA_onethird_N500_s190001 has been done
# MA_onethird_N1000_s190001 has been done
# MA_onethird_N2000_s190001 has been done
# MA_onethird_N4000_s190001 has been done
# MA_onethird_N8000_s190001 has been done
# MA_half_N250_s190001 has been done
# MA_half_N500_s190001 has been done
# MA_half_N1000_s190001 has been done
# MA_half_N2000_s190001 has been done
# MA_half_N4000_s190001 has been done
# MA_half_N8000_s190001 has been done
# MA_twothirds_N250_s190001 has been done
# MA_twothirds_N500_s190001 has been done
# MA_twothirds_N1000_s190001 has been done
# MA_twothirds_N2000_s190001 has been done
# MA_twothirds_N4000_s190001 has been done
# MA_twothirds_N8000_s190001 has been done
# MA_full_N250_s190001 has been done
# MA_full_N500_s190001 has been done
# MA_full_N1000_s190001 has been done
# MA_full_N2000_s190001 has been done
# MA_full_N4000_s190001 has been done
# MA_full_N8000_s190001 has been done
# MA_onethird_N250_s200000 has been done
# MA_onethird_N500_s200000 has been done
# MA_onethird_N1000_s200000 has been done
# MA_onethird_N2000_s200000 has been done
# MA_onethird_N4000_s200000 has been done
# MA_onethird_N8000_s200000 has been done
# MA_half_N250_s200000 has been done
# MA_half_N500_s200000 has been done
# MA_half_N1000_s200000 has been done
# MA_half_N2000_s200000 has been done
# MA_half_N4000_s200000 has been done
# MA_half_N8000_s200000 has been done
# MA_twothirds_N250_s200000 has been done
# MA_twothirds_N500_s200000 has been done
# MA_twothirds_N1000_s200000 has been done
# MA_twothirds_N2000_s200000 has been done
# MA_twothirds_N4000_s200000 has been done
# MA_twothirds_N8000_s200000 has been done
# MA_full_N250_s200000 has been done
# MA_full_N500_s200000 has been done
# MA_full_N1000_s200000 has been done
# MA_full_N2000_s200000 has been done
# MA_full_N4000_s200000 has been done
# MA_full_N8000_s200000 has been done
# MA_onethird_N250_s200001 has been done
# MA_onethird_N500_s200001 has been done
# MA_onethird_N1000_s200001 has been done
# MA_onethird_N2000_s200001 has been done
# MA_onethird_N4000_s200001 has been done
# MA_onethird_N8000_s200001 has been done
# MA_half_N250_s200001 has been done
# MA_half_N500_s200001 has been done
# MA_half_N1000_s200001 has been done
# MA_half_N2000_s200001 has been done
# MA_half_N4000_s200001 has been done
# MA_half_N8000_s200001 has been done
# MA_twothirds_N250_s200001 has been done
# MA_twothirds_N500_s200001 has been done
# MA_twothirds_N1000_s200001 has been done
# MA_twothirds_N2000_s200001 has been done
# MA_twothirds_N4000_s200001 has been done
# MA_twothirds_N8000_s200001 has been done
# MA_full_N250_s200001 has been done
# MA_full_N500_s200001 has been done
# MA_full_N1000_s200001 has been done
# MA_full_N2000_s200001 has been done
# MA_full_N4000_s200001 has been done
# MA_full_N8000_s200001 has been done
# MA_onethird_N250_s10002 has been done
# MA_onethird_N500_s10002 has been done
# MA_onethird_N1000_s10002 has been done
# MA_onethird_N2000_s10002 has been done
# MA_onethird_N4000_s10002 has been done
# MA_onethird_N8000_s10002 has been done
# MA_half_N250_s10002 has been done
# MA_half_N500_s10002 has been done
# MA_half_N1000_s10002 has been done
# MA_half_N2000_s10002 has been done
# MA_half_N4000_s10002 has been done
# MA_half_N8000_s10002 has been done
# MA_twothirds_N250_s10002 has been done
# MA_twothirds_N500_s10002 has been done
# MA_twothirds_N1000_s10002 has been done
# MA_twothirds_N2000_s10002 has been done
# MA_twothirds_N4000_s10002 has been done
# MA_twothirds_N8000_s10002 has been done
# MA_full_N250_s10002 has been done
# MA_full_N500_s10002 has been done
# MA_full_N1000_s10002 has been done
# MA_full_N2000_s10002 has been done
# MA_full_N4000_s10002 has been done
# MA_full_N8000_s10002 has been done
# MA_onethird_N250_s20002 has been done
# MA_onethird_N500_s20002 has been done
# MA_onethird_N1000_s20002 has been done
# MA_onethird_N2000_s20002 has been done
# MA_onethird_N4000_s20002 has been done
# MA_onethird_N8000_s20002 has been done
# MA_half_N250_s20002 has been done
# MA_half_N500_s20002 has been done
# MA_half_N1000_s20002 has been done
# MA_half_N2000_s20002 has been done
# MA_half_N4000_s20002 has been done
# MA_half_N8000_s20002 has been done
# MA_twothirds_N250_s20002 has been done
# MA_twothirds_N500_s20002 has been done
# MA_twothirds_N1000_s20002 has been done
# MA_twothirds_N2000_s20002 has been done
# MA_twothirds_N4000_s20002 has been done
# MA_twothirds_N8000_s20002 has been done
# MA_full_N250_s20002 has been done
# MA_full_N500_s20002 has been done
# MA_full_N1000_s20002 has been done
# MA_full_N2000_s20002 has been done
# MA_full_N4000_s20002 has been done
# MA_full_N8000_s20002 has been done
# MA_onethird_N250_s30002 has been done
# MA_onethird_N500_s30002 has been done
# MA_onethird_N1000_s30002 has been done
# MA_onethird_N2000_s30002 has been done
# MA_onethird_N4000_s30002 has been done
# MA_onethird_N8000_s30002 has been done
# MA_half_N250_s30002 has been done
# MA_half_N500_s30002 has been done
# MA_half_N1000_s30002 has been done
# MA_half_N2000_s30002 has been done
# MA_half_N4000_s30002 has been done
# MA_half_N8000_s30002 has been done
# MA_twothirds_N250_s30002 has been done
# MA_twothirds_N500_s30002 has been done
# MA_twothirds_N1000_s30002 has been done
# MA_twothirds_N2000_s30002 has been done
# MA_twothirds_N4000_s30002 has been done
# MA_twothirds_N8000_s30002 has been done
# MA_full_N250_s30002 has been done
# MA_full_N500_s30002 has been done
# MA_full_N1000_s30002 has been done
# MA_full_N2000_s30002 has been done
# MA_full_N4000_s30002 has been done
# MA_full_N8000_s30002 has been done
# MA_onethird_N250_s40002 has been done
# MA_onethird_N500_s40002 has been done
# MA_onethird_N1000_s40002 has been done
# MA_onethird_N2000_s40002 has been done
# MA_onethird_N4000_s40002 has been done
# MA_onethird_N8000_s40002 has been done
# MA_half_N250_s40002 has been done
# MA_half_N500_s40002 has been done
# MA_half_N1000_s40002 has been done
# MA_half_N2000_s40002 has been done
# MA_half_N4000_s40002 has been done
# MA_half_N8000_s40002 has been done
# MA_twothirds_N250_s40002 has been done
# MA_twothirds_N500_s40002 has been done
# MA_twothirds_N1000_s40002 has been done
# MA_twothirds_N2000_s40002 has been done
# MA_twothirds_N4000_s40002 has been done
# MA_twothirds_N8000_s40002 has been done
# MA_full_N250_s40002 has been done
# MA_full_N500_s40002 has been done
# MA_full_N1000_s40002 has been done
# MA_full_N2000_s40002 has been done
# MA_full_N4000_s40002 has been done
# MA_full_N8000_s40002 has been done
# MA_onethird_N250_s50002 has been done
# MA_onethird_N500_s50002 has been done
# MA_onethird_N1000_s50002 has been done
# MA_onethird_N2000_s50002 has been done
# MA_onethird_N4000_s50002 has been done
# MA_onethird_N8000_s50002 has been done
# MA_half_N250_s50002 has been done
# MA_half_N500_s50002 has been done
# MA_half_N1000_s50002 has been done
# MA_half_N2000_s50002 has been done
# MA_half_N4000_s50002 has been done
# MA_half_N8000_s50002 has been done
# MA_twothirds_N250_s50002 has been done
# MA_twothirds_N500_s50002 has been done
# MA_twothirds_N1000_s50002 has been done
# MA_twothirds_N2000_s50002 has been done
# MA_twothirds_N4000_s50002 has been done
# MA_twothirds_N8000_s50002 has been done
# MA_full_N250_s50002 has been done
# MA_full_N500_s50002 has been done
# MA_full_N1000_s50002 has been done
# MA_full_N2000_s50002 has been done
# MA_full_N4000_s50002 has been done
# MA_full_N8000_s50002 has been done
# MA_onethird_N250_s60002 has been done
# MA_onethird_N500_s60002 has been done
# MA_onethird_N1000_s60002 has been done
# MA_onethird_N2000_s60002 has been done
# MA_onethird_N4000_s60002 has been done
# MA_onethird_N8000_s60002 has been done
# MA_half_N250_s60002 has been done
# MA_half_N500_s60002 has been done
# MA_half_N1000_s60002 has been done
# MA_half_N2000_s60002 has been done
# MA_half_N4000_s60002 has been done
# MA_half_N8000_s60002 has been done
# MA_twothirds_N250_s60002 has been done
# MA_twothirds_N500_s60002 has been done
# MA_twothirds_N1000_s60002 has been done
# MA_twothirds_N2000_s60002 has been done
# MA_twothirds_N4000_s60002 has been done
# MA_twothirds_N8000_s60002 has been done
# MA_full_N250_s60002 has been done
# MA_full_N500_s60002 has been done
# MA_full_N1000_s60002 has been done
# MA_full_N2000_s60002 has been done
# MA_full_N4000_s60002 has been done
# MA_full_N8000_s60002 has been done
# MA_onethird_N250_s70002 has been done
# MA_onethird_N500_s70002 has been done
# MA_onethird_N1000_s70002 has been done
# MA_onethird_N2000_s70002 has been done
# MA_onethird_N4000_s70002 has been done
# MA_onethird_N8000_s70002 has been done
# MA_half_N250_s70002 has been done
# MA_half_N500_s70002 has been done
# MA_half_N1000_s70002 has been done
# MA_half_N2000_s70002 has been done
# MA_half_N4000_s70002 has been done
# MA_half_N8000_s70002 has been done
# MA_twothirds_N250_s70002 has been done
# MA_twothirds_N500_s70002 has been done
# MA_twothirds_N1000_s70002 has been done
# MA_twothirds_N2000_s70002 has been done
# MA_twothirds_N4000_s70002 has been done
# MA_twothirds_N8000_s70002 has been done
# MA_full_N250_s70002 has been done
# MA_full_N500_s70002 has been done
# MA_full_N1000_s70002 has been done
# MA_full_N2000_s70002 has been done
# MA_full_N4000_s70002 has been done
# MA_full_N8000_s70002 has been done
# MA_onethird_N250_s80002 has been done
# MA_onethird_N500_s80002 has been done
# MA_onethird_N1000_s80002 has been done
# MA_onethird_N2000_s80002 has been done
# MA_onethird_N4000_s80002 has been done
# MA_onethird_N8000_s80002 has been done
# MA_half_N250_s80002 has been done
# MA_half_N500_s80002 has been done
# MA_half_N1000_s80002 has been done
# MA_half_N2000_s80002 has been done
# MA_half_N4000_s80002 has been done
# MA_half_N8000_s80002 has been done
# MA_twothirds_N250_s80002 has been done
# MA_twothirds_N500_s80002 has been done
# MA_twothirds_N1000_s80002 has been done
# MA_twothirds_N2000_s80002 has been done
# MA_twothirds_N4000_s80002 has been done
# MA_twothirds_N8000_s80002 has been done
# MA_full_N250_s80002 has been done
# MA_full_N500_s80002 has been done
# MA_full_N1000_s80002 has been done
# MA_full_N2000_s80002 has been done
# MA_full_N4000_s80002 has been done
# MA_full_N8000_s80002 has been done
# MA_onethird_N250_s90002 has been done
# MA_onethird_N500_s90002 has been done
# MA_onethird_N1000_s90002 has been done
# MA_onethird_N2000_s90002 has been done
# MA_onethird_N4000_s90002 has been done
# MA_onethird_N8000_s90002 has been done
# MA_half_N250_s90002 has been done
# MA_half_N500_s90002 has been done
# MA_half_N1000_s90002 has been done
# MA_half_N2000_s90002 has been done
# MA_half_N4000_s90002 has been done
# MA_half_N8000_s90002 has been done
# MA_twothirds_N250_s90002 has been done
# MA_twothirds_N500_s90002 has been done
# MA_twothirds_N1000_s90002 has been done
# MA_twothirds_N2000_s90002 has been done
# MA_twothirds_N4000_s90002 has been done
# MA_twothirds_N8000_s90002 has been done
# MA_full_N250_s90002 has been done
# MA_full_N500_s90002 has been done
# MA_full_N1000_s90002 has been done
# MA_full_N2000_s90002 has been done
# MA_full_N4000_s90002 has been done
# MA_full_N8000_s90002 has been done
# MA_onethird_N250_s100002 has been done
# MA_onethird_N500_s100002 has been done
# MA_onethird_N1000_s100002 has been done
# MA_onethird_N2000_s100002 has been done
# MA_onethird_N4000_s100002 has been done
# MA_onethird_N8000_s100002 has been done
# MA_half_N250_s100002 has been done
# MA_half_N500_s100002 has been done
# MA_half_N1000_s100002 has been done
# MA_half_N2000_s100002 has been done
# MA_half_N4000_s100002 has been done
# MA_half_N8000_s100002 has been done
# MA_twothirds_N250_s100002 has been done
# MA_twothirds_N500_s100002 has been done
# MA_twothirds_N1000_s100002 has been done
# MA_twothirds_N2000_s100002 has been done
# MA_twothirds_N4000_s100002 has been done
# MA_twothirds_N8000_s100002 has been done
# MA_full_N250_s100002 has been done
# MA_full_N500_s100002 has been done
# MA_full_N1000_s100002 has been done
# MA_full_N2000_s100002 has been done
# MA_full_N4000_s100002 has been done
# MA_full_N8000_s100002 has been done
